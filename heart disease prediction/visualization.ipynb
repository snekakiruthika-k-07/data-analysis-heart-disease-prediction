# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing the dataset
df = pd.read_csv("heart disease prediction.csv")
df
# Out:
#      age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145  233.0    1      0.0    150.0    0.0      2.3
# 1     37    1   2       130  250.0    0      1.0    187.0    0.0      3.5
# 2     41    0   1       130  204.0    0      0.0    172.0    0.0      1.4
# 3     56    1   1       120  236.0    0      1.0    178.0    0.0      0.8
# 4     57    0   0       120  354.0    0      1.0    163.0    1.0      0.6
# ..   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 304   57    0   0       140  241.0    0      1.0    123.0    1.0      0.2
# 305   45    1   3       110  264.0    0      1.0    132.0    0.0      1.2
# 306   68    1   0       144  193.0    1      1.0    141.0    0.0      3.4
# 307   57    1   0       130  131.0    0      1.0    115.0    1.0      1.2
# 308   57    0   1       130  236.0    0      0.0    174.0    0.0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# ...

# %%
#displaying the columns 
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
#visualization techinques 
#barchart 
columns_to_change =['sex', 'target']
df[columns_to_change].value_counts().plot(kind='bar',color='green')
plt.title("HEART DISEASE PREDICTION")
plt.show()

# %%
#piechart
df.plot(kind='pie',x='sex',y='target')
plt.show()

# %%
#histogram
sns.histplot(data=df, x='age', y='target', hue='target', palette='Set1')
plt.xlabel("AGE")
plt.ylabel("TARGET")
plt.title("AGE VS TARGET")
plt.show()

# %%
#areachart 
df.plot(kind='area',x='chol',y='age',color='crimson')
plt.xlabel("CHOLESTROL")
plt.ylabel("AGE")
plt.show()

# %%
#scatterplot
sns.scatterplot(data=df, x='trestbps', y='target', hue='target', palette='Set1')
plt.title("HEART DISEASE PREDICTION")
plt.show()

# %%
#boxplot
sns.boxplot(df['age'])
plt.title("HEART DISEASE PREDICTION")
plt.show()

# %%
#heatmap 
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix,annot=True)
plt.show()
